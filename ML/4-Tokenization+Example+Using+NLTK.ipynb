# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\Users\Bhavik\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: click in c:\Users\Bhavik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\Users\Bhavik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\Bhavik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (2026.2.19)
# Requirement already satisfied: tqdm in c:\Users\Bhavik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\Bhavik\AppData\Roaming\Python\Python312\site-packages (from click->nltk) (0.4.6)

# %%
corpus = """Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
##  Tokenization
## Sentence-->paragraphs
import sys
import nltk
from nltk.tokenize import sent_tokenize

print(sys.executable)  # shows which Python your notebook kernel is using
nltk.download("punkt_tab")  # required for nltk 3.9.x
nltk.download("punkt")
# Out:
# c:\Users\Bhavik\AppData\Local\Programs\Python\Python312\python.exe
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Bhavik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Bhavik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
## Tokenization
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
